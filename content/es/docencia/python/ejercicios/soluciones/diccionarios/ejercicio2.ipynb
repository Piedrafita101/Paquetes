# %% [markdown]
# <a href="https://colab.research.google.com/github/Piedrafita101/Paquetes/blob/main/content/es/docencia/python/ejercicios/soluciones/diccionarios/ejercicio2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import torch

# %%
import matplotlib.pyplot as plt
